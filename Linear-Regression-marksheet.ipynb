# %%
import warnings
warnings.simplefilter('ignore')

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.DataFrame(pd.read_excel("marksheet.xlsx"))

# %%
data
# Out:
#      SNO  Physic  Maths  Chemistry  English  Csc  Total  Cutoff     Admit  \
# 0      1      88     97         88       86   80    439   185.0  0.750000
# 1      2      89     91         73       95  100    448   172.0  0.533333
# 2      3      99     70         78       79   87    413   158.5  0.308333
# 3      4      80     82         79       74   75    390   161.5  0.358333
# 4      5      88     83         96       71   90    428   175.0  0.583333
# ..   ...     ...    ...        ...      ...  ...    ...     ...       ...
# 495  496      89     96         79       88   89    441   180.0  0.666667
# 496  497      96     81         83       94   98    452   170.5  0.508333
# 497  498      96     89         94       91   81    451   184.0  0.733333
# 498  499      73     85         97       80   99    434   170.0  0.500000
# 499  500      99     83         91       72   80    425   178.0  0.633333
#
#      min value
# 0        140.0
# 1          NaN
# 2          NaN
# ...

# %%
data = data.drop(['SNO', 'Physic', 'Maths', 'Chemistry', 'English', 'Csc','Cutoff', 'min value'], axis = 1)

# %%
data
# Out:
#      Total     Admit
# 0      439  0.750000
# 1      448  0.533333
# 2      413  0.308333
# 3      390  0.358333
# 4      428  0.583333
# ..     ...       ...
# 495    441  0.666667
# 496    452  0.508333
# 497    451  0.733333
# 498    434  0.500000
# 499    425  0.633333
#
# [500 rows x 2 columns]

# %%
x = data.iloc[:,0]

# %%
x.shape
# Out:
# (500,)

# %%
x = data.iloc[:,0].values.reshape(-1,1)

# %%
x.shape
# Out:
# (500, 1)

# %%
x
# Out:
# array([[439],
#        [448],
#        [413],
#        [390],
#        [428],
#        [428],
#        [439],
#        [389],
#        [434],
#        [424],
#        [427],
#        [418],
#        [447],
#        [458],
#        [386],
#        [451],
#        [422],
#        [409],
#        [434],
#        [448],
#        [449],
#        [394],
#        [452],
#        [451],
#        [443],
#        [400],
#        [435],
#        [426],
#        [449],
#        [428],
#        [468],
#        [455],
#        [419],
#        [410],
#        [407],
#        [423],
#        [407],
#        [421],
#        [457],
#        [390],
#        [437],
#        [418],
#        [422],
#        [389],
#        [402],
#        [444],
#        [396],
#        [437],
#        [425],
#        [436],
#        [413],
#        [431],
#        [407],
#        [427],
#        [390],
#        [447],
#        [442],
#        [433],
#        [441],
#        [462],
#        [424],
#        [431],
# ...

# %%
y = data.iloc[:,-1].values.reshape(-1,1)

# %%
y.shape
# Out:
# (500, 1)

# %%
y
# Out:
# array([[0.75      ],
#        [0.53333333],
#        [0.30833333],
#        [0.35833333],
#        [0.58333333],
#        [0.475     ],
#        [0.64166667],
#        [0.175     ],
#        [0.55      ],
#        [0.575     ],
#        [0.41666667],
#        [0.25833333],
#        [0.475     ],
#        [0.74166667],
#        [0.19166667],
#        [0.56666667],
#        [0.53333333],
#        [0.3       ],
#        [0.35833333],
#        [0.65      ],
#        [0.75      ],
#        [0.19166667],
#        [0.58333333],
#        [0.75833333],
#        [0.65833333],
#        [0.33333333],
#        [0.40833333],
#        [0.43333333],
#        [0.74166667],
#        [0.78333333],
#        [0.79166667],
#        [0.73333333],
#        [0.51666667],
#        [0.25833333],
#        [0.20833333],
#        [0.46666667],
#        [0.5       ],
#        [0.66666667],
#        [0.8       ],
#        [0.3       ],
#        [0.525     ],
#        [0.45      ],
#        [0.35      ],
# ...

# %%
plt.scatter(x,y)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)

# %%
x_train.shape
# Out:
# (400, 1)

# %%
x_test.shape
# Out:
# (100, 1)

# %%
y_train.shape
# Out:
# (400, 1)

# %%
y_test.shape
# Out:
# (100, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lm.predict(x_test)

# %%
check = pd.DataFrame(x_test,columns =['Total'])

# %%
check
# Out:
#     Total
# 0     414
# 1     450
# 2     461
# 3     409
# 4     405
# ..    ...
# 95    441
# 96    442
# 97    446
# 98    424
# 99    418
#
# [100 rows x 1 columns]

# %%
check['Admit Actual'] = y_test

# %%
check
# Out:
#     Total  Admit Actual
# 0     414      0.658333
# 1     450      0.816667
# 2     461      0.583333
# 3     409      0.366667
# 4     405      0.600000
# ..    ...           ...
# 95    441      0.700000
# 96    442      0.716667
# 97    446      0.500000
# 98    424      0.466667
# 99    418      0.616667
#
# [100 rows x 2 columns]

# %%
check['Admit Predicted'] = y_pred

# %%
check
# Out:
#     Total  Admit Actual  Admit Predicted
# 0     414      0.658333         0.431626
# 1     450      0.816667         0.655568
# 2     461      0.583333         0.723994
# 3     409      0.366667         0.400523
# 4     405      0.600000         0.375641
# ..    ...           ...              ...
# 95    441      0.700000         0.599582
# 96    442      0.716667         0.605803
# 97    446      0.500000         0.630685
# 98    424      0.466667         0.493832
# 99    418      0.616667         0.456509
#
# [100 rows x 3 columns]

# %%
plt.scatter(x,y, color = 'blue')
plt.plot(x_test,y_pred,color = 'red')
